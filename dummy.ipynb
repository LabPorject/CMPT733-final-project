# %%
import scripts.query_database as function
import pandas as pd

# %%
# get all reviews
reviews_db = function.get_reviews()
reviews_db.head(5)
# Out:
#          _id  tmdb_id                                             review
# 0  tt0004972      618  [{'author': 'prabhushakti', 'rating': 10.0, 'u...
# 1  tt0008431   285807  [{'author': 'Le_Schpountz', 'rating': 6.0, 'ur...
# 2  tt0009062    48214  [{'author': 'germish', 'rating': 9.5, 'url': '...
# 3  tt0009143   463115  [{'author': '27B/6', 'rating': None, 'url': 'h...
# 4  tt0010058   352098  [{'author': 'ObscurHollywood', 'rating': None,...

# %%
# get all movies, no constrains 
combined_db = function.get_combined()
combined_db.head(5)
# Out:
#          _id                    primaryTitle                   originalTitle  \
# 0  tt0000574     The Story of the Kelly Gang     The Story of the Kelly Gang
# 1  tt0000615              Robbery Under Arms              Robbery Under Arms
# 2  tt0000679  The Fairylogue and Radio-Plays  The Fairylogue and Radio-Plays
# 3  tt0000846            Un día en Xochimilco            Un día en Xochimilco
# 4  tt0000867                 Fiesta de toros                 Fiesta de toros
#
#   isAdult release_year  runtimeMinutes  \
# 0       0         1906            70.0
# 1       0         1907            60.0
# 2       0         1908           120.0
# 3       0         1909             0.0
# 4       0         1909             0.0
#
#                                               genres  imdb_avgRating  \
# 0  [Action, Adventure, Biography, History, Drama,...             6.1
# 1                                            [Drama]             4.5
# 2                               [Adventure, Fantasy]             5.2
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#    imdb_numVotes                     Directors  ...  \
# 0          622.0                [Charles Tait]  ...
# 1           14.0            [Charles MacMahon]  ...
# 2           35.0  [Francis Boggs, Otis Turner]  ...
# 3            NaN               [Hermanos Alva]  ...
# 4            NaN               [Hermanos Alva]  ...
#
#                               top_10_cast_popularity  num_of_crew  \
# 0                                         [0.6, 0.6]          5.0
# 1           [0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6]          2.0
# 2  [1.4, 1.237, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6...          4.0
# 3                                                NaN          NaN
# 4                                                NaN          NaN
#
#   top_10_crew_popularity_mean  \
# 0                     0.60000
# 1                     0.60000
# 2                     0.81625
# 3                         NaN
# 4                         NaN
#
#                                                crews  \
# 0  [Charles Tait, Millard Johnson, Orrie Perry, R...
# 1                [Charles MacMahon, C. Byers Coates]
# 2  [L. Frank Baum, Francis Boggs, Otis Turner, Na...
# 3                                                NaN
# 4                                                NaN
#
#       top_10_crew_popularity  tmdb_avgRating  tmdb_numVotes  \
# 0  [0.6, 0.6, 0.6, 0.6, 0.6]             5.3             21
# 1                 [0.6, 0.6]             1.0              1
# 2   [1.237, 0.828, 0.6, 0.6]             1.0              1
# 3                        NaN             5.0              1
# 4                        NaN             5.0              1
#
#              Writers homepage belongs_to_collection
# 0                NaN      NaN                   NaN
# 1  [Rolf Boldrewood]      NaN                   NaN
# 2    [L. Frank Baum]      NaN                   NaN
# 3                NaN      NaN                   NaN
# 4                NaN      NaN                   NaN
#
# [5 rows x 35 columns]

# %%
# get 50 sample movies
sample_db = function.get_combined(sample_size=50)
sample_db.head(5)
# Out:
#          _id                    primaryTitle                   originalTitle  \
# 0  tt0000574     The Story of the Kelly Gang     The Story of the Kelly Gang
# 1  tt0000615              Robbery Under Arms              Robbery Under Arms
# 2  tt0000679  The Fairylogue and Radio-Plays  The Fairylogue and Radio-Plays
# 3  tt0000846            Un día en Xochimilco            Un día en Xochimilco
# 4  tt0000867                 Fiesta de toros                 Fiesta de toros
#
#    isAdult  release_year  runtimeMinutes  \
# 0        0          1906            70.0
# 1        0          1907            60.0
# 2        0          1908           120.0
# 3        0          1909             0.0
# 4        0          1909             0.0
#
#                                               genres  imdb_avgRating  \
# 0  [Action, Adventure, Biography, History, Drama,...             6.1
# 1                                            [Drama]             4.5
# 2                               [Adventure, Fantasy]             5.2
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#    imdb_numVotes                     Directors  ... num_of_cast  \
# 0          622.0                [Charles Tait]  ...         2.0
# 1           14.0            [Charles MacMahon]  ...         8.0
# 2           35.0  [Francis Boggs, Otis Turner]  ...        11.0
# 3            NaN               [Hermanos Alva]  ...         NaN
# 4            NaN               [Hermanos Alva]  ...         NaN
#
#    top_10_cast_popularity_mean  \
# 0                       0.6000
# 1                       0.6000
# 2                       0.7437
# 3                          NaN
# 4                          NaN
#
#                               top_10_cast_popularity num_of_crew  \
# 0                                         [0.6, 0.6]         5.0
# 1           [0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6]         2.0
# 2  [1.4, 1.237, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6...         4.0
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#    top_10_crew_popularity_mean  \
# 0                      0.60000
# 1                      0.60000
# 2                      0.81625
# 3                          NaN
# 4                          NaN
#
#                                                crews  \
# 0  [Charles Tait, Millard Johnson, Orrie Perry, R...
# 1                [Charles MacMahon, C. Byers Coates]
# 2  [L. Frank Baum, Francis Boggs, Otis Turner, Na...
# 3                                                NaN
# 4                                                NaN
#
#       top_10_crew_popularity tmdb_avgRating tmdb_numVotes            Writers
# 0  [0.6, 0.6, 0.6, 0.6, 0.6]            5.3            21                NaN
# 1                 [0.6, 0.6]            1.0             1  [Rolf Boldrewood]
# 2   [1.237, 0.828, 0.6, 0.6]            1.0             1    [L. Frank Baum]
# 3                        NaN            5.0             1                NaN
# 4                        NaN            5.0             1                NaN
#
# [5 rows x 33 columns]

# %%
# get movies later than 1960
new_db = function.get_combined(release_year_cutoff=1960)
new_db.head(5)
# Out:
#          _id            primaryTitle           originalTitle  isAdult  \
# 0  tt0011216          Spanish Fiesta       La fête espagnole        0
# 1  tt0011801        Tötet nicht mehr        Tötet nicht mehr        0
# 2  tt0015414  La tierra de los toros  La tierra de los toros        0
# 3  tt0015724           Dama de noche           Dama de noche        0
# 4  tt0016906              Frivolinas              Frivolinas        0
#
#    release_year  runtimeMinutes                               genres  \
# 0          2019            67.0                              [Drama]
# 1          2019           127.0               [Action, Crime, Drama]
# 2          2000            60.0                              [Drama]
# 3          1993           102.0  [Drama, Mystery, Romance, Thriller]
# 4          2014            80.0                    [Comedy, Musical]
#
#    imdb_avgRating  imdb_numVotes                  Directors  ...  \
# 0             6.6           22.0           [Germaine Dulac]  ...
# 1             NaN            NaN                       None  ...
# 2             5.4           11.0                   Musidora  ...
# 3             6.0           21.0  [Eva López Sánchez, None]  ...
# 4             5.6           15.0          [Arturo Carballo]  ...
#
#                               top_10_cast_popularity num_of_crew  \
# 0                       [1.4, 1.22, 1.095, 0.6, 0.6]         5.0
# 1  [1.532, 1.4, 1.4, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6...         6.0
# 2                                         [0.6, 0.6]         1.0
# 3                 [1.094, 0.84, 0.84, 0.6, 0.6, 0.6]         6.0
# 4                     [0.6, 0.6, 0.6, 0.6, 0.6, 0.6]         2.0
#
#    top_10_crew_popularity_mean  \
# 0                     0.676000
# 1                     0.733333
# 2                     0.600000
# 3                     0.784667
# 4                     0.600000
#
#                                                crews  \
# 0  [Germaine Dulac, Serge Sandberg, Paul Parguel,...
# 1  [Gerhard Lamprecht, Willi Herrmann, Lupu Pick,...
# 2                                         [Musidora]
# 3  [Rodrigo Prieto, Hubert Barrero, Eva López Sán...
# 4                  [Arturo Carballo, Ramón de Baños]
#
#              top_10_crew_popularity  tmdb_avgRating  tmdb_numVotes  \
# 0        [0.98, 0.6, 0.6, 0.6, 0.6]             6.0              1
# 1    [1.4, 0.6, 0.6, 0.6, 0.6, 0.6]             0.0              0
# 2                             [0.6]             0.0              0
# 3  [1.708, 0.6, 0.6, 0.6, 0.6, 0.6]             8.8              4
# 4                        [0.6, 0.6]             0.0              0
#
#                                             homepage tagline  \
# 0                                                NaN     NaN
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3  http://www.elccc.com.mx/sitio/index.php/produc...     NaN
# 4                                                NaN     NaN
#
#   belongs_to_collection
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 35 columns]

# %%
# get all possible column names
print(function.get_all_columns_name())
# Out:
# ['_id', 'primaryTitle', 'originalTitle', 'isAdult', 'release_year', 'release_date', 'runtimeMinutes', 'genres', 'imdb_avgRating', 'imdb_numVotes', 'Directors', 'casts', 'tmdb_id', 'poster_path', 'original_language', 'popularity', 'budget', 'revenue', 'status', 'tagline', 'overview', 'company_name', 'keywords_name', 'num_of_cast', 'top_10_cast_popularity_mean', 'top_10_cast_popularity', 'num_of_crew', 'top_10_crew_popularity_mean', 'crews', 'top_10_crew_popularity', 'tmdb_avgRating', 'tmdb_numVotes', 'Writers', 'homepage', 'belongs_to_collection']

# %%
# drop selected columns to reduce query size
drop_cols = ['overview', 'tagline', 'originalTitle', 'num_of_cast', 'top_10_cast_popularity_mean'
             , 'top_10_cast_popularity', 'num_of_crew', 'top_10_crew_popularity_mean', 'crews'
             , 'top_10_crew_popularity', 'homepage']
dropped_db = function.get_combined(drop_lst=drop_cols)
dropped_db.head(5)
# Out:
#          _id                    primaryTitle isAdult release_year  \
# 0  tt0000574     The Story of the Kelly Gang       0         1906
# 1  tt0000615              Robbery Under Arms       0         1907
# 2  tt0000679  The Fairylogue and Radio-Plays       0         1908
# 3  tt0000846            Un día en Xochimilco       0         1909
# 4  tt0000867                 Fiesta de toros       0         1909
#
#    runtimeMinutes                                             genres  \
# 0            70.0  [Action, Adventure, Biography, History, Drama,...
# 1            60.0                                            [Drama]
# 2           120.0                               [Adventure, Fantasy]
# 3             0.0                                                NaN
# 4             0.0                                                NaN
#
#    imdb_avgRating  imdb_numVotes                     Directors  \
# 0             6.1          622.0                [Charles Tait]
# 1             4.5           14.0            [Charles MacMahon]
# 2             5.2           35.0  [Francis Boggs, Otis Turner]
# 3             NaN            NaN               [Hermanos Alva]
# 4             NaN            NaN               [Hermanos Alva]
#
#                                                casts  ...  budget revenue  \
# 0                        [Elizabeth Tait, John Tait]  ...       0       0
# 1  [Jim Gerald, J. Williams, George Merriman, Lan...  ...       0       0
# 2  [Frank Burns, L. Frank Baum, George E. Wilson,...  ...       0       0
# 3                                                NaN  ...       0       0
# 4                                                NaN  ...       0       0
#
#      status  release_date                         company_name  \
# 0  Released    1906-12-26   [Johnson and Gibson, J. & N. Tait]
# 1  Released    1907-10-01      [MacMahon's Exquisite Pictures]
# 2  Released    1908-09-23  [The Radio Play Company of America]
# 3  Released    1909-01-01                                  NaN
# 4  Released    1909-01-01                                  NaN
#
#                         keywords_name tmdb_avgRating tmdb_numVotes  \
# 0  [silent film, partially lost film]            5.3            21
# 1                                 NaN            1.0             1
# 2                       [silent film]            1.0             1
# 3                                 NaN            5.0             1
# 4                                 NaN            5.0             1
#
#              Writers belongs_to_collection
# 0                NaN                   NaN
# 1  [Rolf Boldrewood]                   NaN
# 2    [L. Frank Baum]                   NaN
# 3                NaN                   NaN
# 4                NaN                   NaN
#
# [5 rows x 24 columns]

# %%
function.get_combined(1980, drop_cols, 100)
# Out:
#           _id                               primaryTitle  isAdult  \
# 0   tt0011216                             Spanish Fiesta        0
# 1   tt0011801                           Tötet nicht mehr        0
# 2   tt0015414                     La tierra de los toros        0
# 3   tt0015724                              Dama de noche        0
# 4   tt0016906                                 Frivolinas        0
# 5   tt0019996                                    Hongxia        0
# 6   tt0035423                             Kate & Leopold        0
# 7   tt0036177                         Muhomatsu no issho        0
# 8   tt0036606                Another Time, Another Place        0
# 9   tt0038687                         Let There Be Light        0
# 10  tt0057461                     La rosa de los vientos        0
# 11  tt0057713                        Threshold of Spring        0
# 12  tt0059325                                Born in '45        0
# 13  tt0059900             Wenn du groß bist, lieber Adam        0
# 14  tt0062181                               Rece do góry        0
# 15  tt0062336  El Tango del Viudo y Su Espejo Deformante        0
# 16  tt0064730                 Japan Organized Crime Boss        0
# 17  tt0064820                     The Plot Against Harry        0
# 18  tt0065188                    Vojtech, receny sirotek        0
# 19  tt0065392                         Bucharest Memories        0
# 20  tt0065530                     Le cercle des passions        0
# 21  tt0066020                                Lucky Seven        0
# 22  tt0066151                            Ninja Destroyer        0
# 23  tt0066498                                    The Ear        0
#
#     release_year  runtimeMinutes                               genres  \
# 0           2019            67.0                              [Drama]
# 1           2019           127.0               [Action, Crime, Drama]
# 2           2000            60.0                              [Drama]
# 3           1993           102.0  [Drama, Mystery, Romance, Thriller]
# 4           2014            80.0                    [Comedy, Musical]
# 5           2011            94.0                             [Action]
# 6           2001           118.0           [Comedy, Fantasy, Romance]
# 7           2008           100.0                  [Action, Adventure]
# 8           1983           118.0                         [Drama, War]
# 9           1980            58.0                   [Documentary, War]
# 10          1983            84.0                     [Drama, Fantasy]
# 11          1983           120.0    [Drama, History, Romance, Family]
# 12          1990           100.0                     [Drama, Romance]
# 13          1990            78.0             [Drama, Fantasy, Comedy]
# 14          1981            76.0                      [Drama, Comedy]
# 15          2020            70.0             [Drama, Fantasy, Horror]
# 16          2000            97.0               [Action, Crime, Drama]
# 17          1989            81.0                             [Comedy]
# 18          1990            80.0                              [Drama]
# 19          2020            72.0                        [Documentary]
# 20          1983           108.0                              [Drama]
# 21          1986            80.0                     [Action, Comedy]
# 22          1986            92.0                  [Action, Adventure]
# 23          1990            94.0           [Drama, Thriller, Mystery]
#
#     imdb_avgRating  imdb_numVotes  \
# 0              6.6           22.0
# 1              NaN            NaN
# 2              5.4           11.0
# 3              6.0           21.0
# 4              5.6           15.0
# 5              6.3           52.0
# 6              6.4        79283.0
# 7              7.3           77.0
# 8              6.5          258.0
# 9              7.4         1650.0
# 10             5.1           16.0
# 11             7.3          128.0
# 12             6.5          212.0
# 13             6.8           26.0
# 14             6.6          304.0
# 15             6.3          135.0
# 16             6.9          182.0
# 17             6.9          287.0
# 18             6.4           25.0
# 19             7.0            7.0
# 20             6.9           44.0
# 21             6.7          236.0
# 22             4.1           78.0
# 23             7.8         2522.0
#
#                                             Directors  \
# 0                                    [Germaine Dulac]
# 1                                                None
# 2                                            Musidora
# 3                           [Eva López Sánchez, None]
# 4                                   [Arturo Carballo]
# 5                                          Wen Yi-Min
# 6                               [James Mangold, None]
# 7                                   [Hiroshi Inagaki]
# 8                             [Michael Radford, None]
# 9                                       [John Huston]
# 10                                  [Patricio Guzmán]
# 11                                        [Tieli Xie]
# 12                                  [Jürgen Böttcher]
# 13                                     [Egon Günther]
# 14                                               None
# 15              [Raoul Ruiz, Valeria Sarmiento, None]
# 16                             [Kinji Fukasaku, None]
# 17                                   [Michael Roemer]
# 18                                       [Zdenek Tyc]
# 19  [Radu Gabrea, Yousif Mohamed Aidaby, Maria Ale...
# 20                                    [Claude d'Anna]
# 21                                    [Chen-Kuo Chao]
# 22                                       [Godfrey Ho]
# 23                                    [Karel Kachyna]
#
#                                               Writers  ... popularity  \
# 0                                      [Louis Delluc]  ...      0.600
# 1                                 [Gerhard Lamprecht]  ...      0.600
# 2                                                 NaN  ...      0.600
# 3            [David Martin del Campo, Hubert Barrero]  ...      1.633
# 4                                                 NaN  ...      0.600
# 5                                                 NaN  ...      0.600
# 6                                     [Steven Rogers]  ...     12.086
# 7                  [Mansaku Itami, Shunsaku Iwashita]  ...      0.997
# 8                  [Jessie Kesson, John Francis Lane]  ...      1.400
# 9                                   [Charles Kaufman]  ...      3.879
# 10                          [Jorge Díaz, Gloria Laso]  ...      1.744
# 11                                           [Roushi]  ...      2.128
# 12                                      [Klaus Poche]  ...      1.004
# 13                                     [Helga Schütz]  ...      1.023
# 14                                 [Andrzej Kostenko]  ...      0.782
# 15  [Omar Saavedra Santis, Daphne du Maurier, Galu...  ...      2.321
# 16                        [Fumio Kônami, Norio Osada]  ...      1.071
# 17                                                NaN  ...      3.288
# 18                       [Jaromir Kacer, Jirí Soukup]  ...      0.840
# 19                                 [George Macovescu]  ...      0.600
# 20  [Gustavo Hernández, Laure Bonin, Francis Lacas...  ...      0.600
# 21                                   [Ching Kang Yao]  ...      4.006
# 22                                [AAV Creative Unit]  ...      0.631
# 23              [Jan Procházka, Ladislav Winkelhöfer]  ...      2.544
#
#       budget   revenue    status  release_date  \
# 0          0         0  Released    1920-01-01
# 1          0         0  Released    1919-01-01
# 2          0         0  Released    1924-01-01
# 3          0         0  Released    1993-05-18
# 4          0         0  Released    1926-01-01
# 5          0         0  Released    1929-07-11
# 6   48000000  76019048  Released    2001-12-25
# 7          0         0  Released    1943-10-28
# 8          0         0  Released    1983-05-13
# 9          0         0  Released    1946-12-16
# 10         0         0  Released    1983-03-19
# 11         0         0  Released    1963-01-03
# 12         0         0  Released    1966-09-26
# 13         0         0  Released    1966-01-01
# 14         0         0  Released    1981-10-09
# 15         0         0  Released    2020-02-21
# 16         0         0  Released    1969-04-17
# 17         0         0  Released    1971-01-27
# 18         0         0  Released    1990-10-01
# 19         0         0  Released    1970-01-02
# 20         0         0  Released    1983-07-06
# 21         0         0  Released    1986-06-28
# 22         0         0  Released    1986-01-01
# 23         0         0  Released    1970-01-01
#
#                                          company_name  \
# 0                            [Les Films Louis Nalpas]
# 1                                     [Rex-Film GmbH]
# 2                                    [Musidora Films]
# 3      [Centro de Capacitación Cinematográfica (CCC)]
# 4           [Ediciones Seleccionadas Arturo Carballo]
# 5                              [Youlian Film Company]
# 6                          [Konrad Pictures, Miramax]
# 7                                                 NaN
# 8   [Umbrella, Associated-Rediffusion Television, ...
# 9                      [U.S. Army Pictorial Services]
# 10                                            [ICAIC]
# 11                                                NaN
# 12  [DEFA, Künstlerische Arbeitsgruppe ''Roter Kre...
# 13                                             [DEFA]
# 14                                                NaN
# 15                                       [Poetastros]
# 16                                     [Toei Company]
# 17                          [King Screen Productions]
# 18                                                NaN
# 19                 [Studioul Cinematografic Bucurest]
# 20  [Dédalus, Fígaro Films, Domiziana Internaziona...
# 21                      [Focus Film (H.K.) Co., Ltd.]
# 22                                                NaN
# 23                         [Filmové studio Barrandov]
#
#                                         keywords_name tmdb_avgRating  \
# 0               [woman director, partially lost film]            6.0
# 1                                                 NaN            0.0
# 2                                    [woman director]            0.0
# 3                                                 NaN            8.8
# 4                                                 NaN            0.0
# 5                                                 NaN            6.3
# 6   [lover (female), love of one's life, time trav...            6.3
# 7                                                 NaN            6.3
# 8                                [eroticism, passion]            5.5
# 9                                       [shell shock]            7.4
# 10                                  [native american]            4.6
# 11                                                NaN            7.9
# 12                                  [berlin, germany]            6.3
# 13                                                NaN            4.6
# 14  [cinema, beirut, lebanon, post-apocalyptic fut...            6.3
# 15                                                NaN            5.5
# 16                                           [yakuza]            8.0
# 17                                                NaN            7.1
# 18                                                NaN            5.3
# 19                                                NaN            0.0
# 20                                                NaN            0.0
# 21                                     [martial arts]            6.5
# 22                                                NaN            6.0
# 23                            [banned before release]            7.4
#
#    tmdb_numVotes  belongs_to_collection
# 0              1                    NaN
# 1              0                    NaN
# 2              0                    NaN
# 3              4                    NaN
# 4              0                    NaN
# 5              3                    NaN
# 6            991                    NaN
# 7              4                    NaN
# 8              4                    NaN
# 9             28                    NaN
# 10             5                    NaN
# 11             9                    NaN
# 12             4                    NaN
# 13             6                    NaN
# 14             4                    NaN
# 15             2                    NaN
# 16             3  Japan's Violent Gangs
# 17             4                    NaN
# 18             3                    NaN
# 19             0                    NaN
# 20             0                    NaN
# 21             2                    NaN
# 22             1                    NaN
# 23            31                    NaN
#
# [24 rows x 24 columns]

# %%
movieLens_db = function.get_movieLens()
movieLens_db.head(5)
# Out:
#         _id  movieLens_Id                               title  \
# 0  tt114709             1                    Toy Story (1995)
# 1  tt113497             2                      Jumanji (1995)
# 2  tt113228             3             Grumpier Old Men (1995)
# 3  tt114885             4            Waiting to Exhale (1995)
# 4  tt113041             5  Father of the Bride Part II (1995)
#
#                                         genres   tmdbId  \
# 0  Adventure|Animation|Children|Comedy|Fantasy    862.0
# 1                   Adventure|Children|Fantasy   8844.0
# 2                               Comedy|Romance  15602.0
# 3                         Comedy|Drama|Romance  31357.0
# 4                                       Comedy  11862.0
#
#                                   individual_ratings  avg_rating
# 0  [4.0, 4.0, 4.5, 2.5, 4.5, 3.5, 4.0, 3.5, 3.0, ...    3.920930
# 1  [4.0, 4.0, 3.0, 3.0, 3.0, 3.5, 4.0, 4.5, 4.0, ...    3.431818
# 2  [4.0, 5.0, 3.0, 3.0, 4.0, 5.0, 3.0, 4.0, 3.0, ...    3.259615
# 3                [3.0, 3.0, 3.0, 3.0, 1.0, 2.0, 1.5]    2.357143
# 4  [5.0, 3.0, 5.0, 3.0, 4.0, 4.0, 2.0, 3.0, 4.0, ...    3.071429

# %%
movieLens_reviews_db = function.get_movieLens_reviews()
movieLens_reviews_db.head(5)
# Out:
#    userId  movieLens_Id  rating   timestamp  imdbId
# 0       1             1     4.0   964982703  114709
# 1       5             1     4.0   847434962  114709
# 2       7             1     4.5  1106635946  114709
# 3      15             1     2.5  1510577970  114709
# 4      17             1     4.5  1305696483  114709

# %%
function.get_combined(2010, drop_cols)
# Out:
#          _id                               primaryTitle  isAdult  \
# 0  tt0011216                             Spanish Fiesta        0
# 1  tt0011801                           Tötet nicht mehr        0
# 2  tt0016906                                 Frivolinas        0
# 3  tt0019996                                    Hongxia        0
# 4  tt0062336  El Tango del Viudo y Su Espejo Deformante        0
# 5  tt0065392                         Bucharest Memories        0
#
#    release_year  runtimeMinutes                    genres  imdb_avgRating  \
# 0          2019            67.0                   [Drama]             6.6
# 1          2019           127.0    [Action, Crime, Drama]             NaN
# 2          2014            80.0         [Comedy, Musical]             5.6
# 3          2011            94.0                  [Action]             6.3
# 4          2020            70.0  [Drama, Fantasy, Horror]             6.3
# 5          2020            72.0             [Documentary]             7.0
#
#    imdb_numVotes                                          Directors  \
# 0           22.0                                   [Germaine Dulac]
# 1            NaN                                               None
# 2           15.0                                  [Arturo Carballo]
# 3           52.0                                         Wen Yi-Min
# 4          135.0              [Raoul Ruiz, Valeria Sarmiento, None]
# 5            7.0  [Radu Gabrea, Yousif Mohamed Aidaby, Maria Ale...
#
#                                              Writers  ... original_language  \
# 0                                     [Louis Delluc]  ...                fr
# 1                                [Gerhard Lamprecht]  ...                de
# 2                                                NaN  ...                es
# 3                                                NaN  ...                zh
# 4  [Omar Saavedra Santis, Daphne du Maurier, Galu...  ...                es
# 5                                 [George Macovescu]  ...                ro
#
#    popularity budget revenue    status  release_date  \
# 0       0.600      0       0  Released    1920-01-01
# 1       0.600      0       0  Released    1919-01-01
# 2       0.600      0       0  Released    1926-01-01
# 3       0.600      0       0  Released    1929-07-11
# 4       2.321      0       0  Released    2020-02-21
# 5       0.600      0       0  Released    1970-01-02
#
#                                 company_name  \
# 0                   [Les Films Louis Nalpas]
# 1                            [Rex-Film GmbH]
# 2  [Ediciones Seleccionadas Arturo Carballo]
# 3                     [Youlian Film Company]
# 4                               [Poetastros]
# 5         [Studioul Cinematografic Bucurest]
#
#                            keywords_name tmdb_avgRating tmdb_numVotes
# 0  [woman director, partially lost film]            6.0             1
# 1                                    NaN            0.0             0
# 2                                    NaN            0.0             0
# 3                                    NaN            6.3             3
# 4                                    NaN            5.5             2
# 5                                    NaN            0.0             0
#
# [6 rows x 23 columns]
