# %%
import scripts.query_database as function
import pandas as pd

# %%
# get all reviews
reviews_db = function.get_reviews()
reviews_db.head(5)
# Out:
#          _id  tmdb_id                                             review
# 0  tt0004972      618  [{'author': 'prabhushakti', 'rating': 10.0, 'u...
# 1  tt0008431   285807  [{'author': 'Le_Schpountz', 'rating': 6.0, 'ur...
# 2  tt0009062    48214  [{'author': 'germish', 'rating': 9.5, 'url': '...
# 3  tt0009143   463115  [{'author': '27B/6', 'rating': None, 'url': 'h...
# 4  tt0010058   352098  [{'author': 'ObscurHollywood', 'rating': None,...

# %%
# get all movies, no constrains 
combined_db = function.get_combined()
combined_db.head(5)
# Out:
#          _id                    primaryTitle                   originalTitle  \
# 0  tt0000574     The Story of the Kelly Gang     The Story of the Kelly Gang
# 1  tt0000615              Robbery Under Arms              Robbery Under Arms
# 2  tt0000679  The Fairylogue and Radio-Plays  The Fairylogue and Radio-Plays
# 3  tt0000846            Un día en Xochimilco            Un día en Xochimilco
# 4  tt0000867                 Fiesta de toros                 Fiesta de toros
#
#    isAdult  release_year  runtimeMinutes  \
# 0        0          1906            70.0
# 1        0          1907            60.0
# 2        0          1908           120.0
# 3        0          1909             0.0
# 4        0          1909             0.0
#
#                                               genres  imdb_avgRating  \
# 0  [Action, Adventure, Biography, History, Drama,...             6.1
# 1                                            [Drama]             4.5
# 2                               [Adventure, Fantasy]             5.2
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#    imdb_numVotes                     Directors  ...  \
# 0          622.0                [Charles Tait]  ...
# 1           14.0            [Charles MacMahon]  ...
# 2           35.0  [Francis Boggs, Otis Turner]  ...
# 3            NaN               [Hermanos Alva]  ...
# 4            NaN               [Hermanos Alva]  ...
#
#                               top_10_cast_popularity  num_of_crew  \
# 0                                         [0.6, 0.6]          5.0
# 1           [0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6]          2.0
# 2  [1.4, 1.237, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6...          4.0
# 3                                                NaN          NaN
# 4                                                NaN          NaN
#
#   top_10_crew_popularity_mean  \
# 0                     0.60000
# 1                     0.60000
# 2                     0.81625
# 3                         NaN
# 4                         NaN
#
#                                                crews  \
# 0  [Charles Tait, Millard Johnson, Orrie Perry, R...
# 1                [Charles MacMahon, C. Byers Coates]
# 2  [L. Frank Baum, Francis Boggs, Otis Turner, Na...
# 3                                                NaN
# 4                                                NaN
#
#       top_10_crew_popularity  tmdb_avgRating  tmdb_numVotes  \
# 0  [0.6, 0.6, 0.6, 0.6, 0.6]             5.3           21.0
# 1                 [0.6, 0.6]             1.0            1.0
# 2   [1.237, 0.828, 0.6, 0.6]             1.0            1.0
# 3                        NaN             5.0            1.0
# 4                        NaN             5.0            1.0
#
#              Writers homepage belongs_to_collection
# 0                NaN      NaN                   NaN
# 1  [Rolf Boldrewood]      NaN                   NaN
# 2    [L. Frank Baum]      NaN                   NaN
# 3                NaN      NaN                   NaN
# 4                NaN      NaN                   NaN
#
# [5 rows x 34 columns]

# %%
# get 50 sample movies
sample_db = function.get_combined(sample_size=50)
sample_db.head(5)
# Out:
#          _id                    primaryTitle                   originalTitle  \
# 0  tt0000574     The Story of the Kelly Gang     The Story of the Kelly Gang
# 1  tt0000615              Robbery Under Arms              Robbery Under Arms
# 2  tt0000679  The Fairylogue and Radio-Plays  The Fairylogue and Radio-Plays
# 3  tt0000846            Un día en Xochimilco            Un día en Xochimilco
# 4  tt0000867                 Fiesta de toros                 Fiesta de toros
#
#    isAdult  release_year  runtimeMinutes  \
# 0        0          1906            70.0
# 1        0          1907            60.0
# 2        0          1908           120.0
# 3        0          1909             0.0
# 4        0          1909             0.0
#
#                                               genres  imdb_avgRating  \
# 0  [Action, Adventure, Biography, History, Drama,...             6.1
# 1                                            [Drama]             4.5
# 2                               [Adventure, Fantasy]             5.2
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#    imdb_numVotes                     Directors  ... num_of_cast  \
# 0          622.0                [Charles Tait]  ...         2.0
# 1           14.0            [Charles MacMahon]  ...         8.0
# 2           35.0  [Francis Boggs, Otis Turner]  ...        11.0
# 3            NaN               [Hermanos Alva]  ...         NaN
# 4            NaN               [Hermanos Alva]  ...         NaN
#
#    top_10_cast_popularity_mean  \
# 0                       0.6000
# 1                       0.6000
# 2                       0.7437
# 3                          NaN
# 4                          NaN
#
#                               top_10_cast_popularity num_of_crew  \
# 0                                         [0.6, 0.6]         5.0
# 1           [0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6]         2.0
# 2  [1.4, 1.237, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6...         4.0
# 3                                                NaN         NaN
# 4                                                NaN         NaN
#
#    top_10_crew_popularity_mean  \
# 0                      0.60000
# 1                      0.60000
# 2                      0.81625
# 3                          NaN
# 4                          NaN
#
#                                                crews  \
# 0  [Charles Tait, Millard Johnson, Orrie Perry, R...
# 1                [Charles MacMahon, C. Byers Coates]
# 2  [L. Frank Baum, Francis Boggs, Otis Turner, Na...
# 3                                                NaN
# 4                                                NaN
#
#       top_10_crew_popularity tmdb_avgRating tmdb_numVotes            Writers
# 0  [0.6, 0.6, 0.6, 0.6, 0.6]            5.3            21                NaN
# 1                 [0.6, 0.6]            1.0             1  [Rolf Boldrewood]
# 2   [1.237, 0.828, 0.6, 0.6]            1.0             1    [L. Frank Baum]
# 3                        NaN            5.0             1                NaN
# 4                        NaN            5.0             1                NaN
#
# [5 rows x 32 columns]

# %%
# get movies later than 1960
new_db = function.get_combined(release_year_cutoff=1960)
new_db.head(5)
# Out:
#          _id            primaryTitle           originalTitle  isAdult  \
# 0  tt0011216          Spanish Fiesta       La fête espagnole        0
# 1  tt0011801        Tötet nicht mehr        Tötet nicht mehr        0
# 2  tt0015414  La tierra de los toros  La tierra de los toros        0
# 3  tt0015724           Dama de noche           Dama de noche        0
# 4  tt0016906              Frivolinas              Frivolinas        0
#
#    release_year  runtimeMinutes                               genres  \
# 0          2019            67.0                              [Drama]
# 1          2019           127.0               [Action, Crime, Drama]
# 2          2000            60.0                              [Drama]
# 3          1993           102.0  [Drama, Mystery, Romance, Thriller]
# 4          2014            80.0                    [Comedy, Musical]
#
#    imdb_avgRating  imdb_numVotes                  Directors  ... num_of_cast  \
# 0             6.6           22.0           [Germaine Dulac]  ...           5
# 1             NaN            NaN                       None  ...          11
# 2             5.4           11.0                   Musidora  ...           2
# 3             6.0           21.0  [Eva López Sánchez, None]  ...           6
# 4             5.6           15.0          [Arturo Carballo]  ...           6
#
#   top_10_cast_popularity_mean  \
# 0                    0.983000
# 1                    0.853200
# 2                    0.600000
# 3                    0.762333
# 4                    0.600000
#
#                               top_10_cast_popularity num_of_crew  \
# 0                       [1.4, 1.22, 1.095, 0.6, 0.6]           5
# 1  [1.532, 1.4, 1.4, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6...           6
# 2                                         [0.6, 0.6]           1
# 3                 [1.094, 0.84, 0.84, 0.6, 0.6, 0.6]           6
# 4                     [0.6, 0.6, 0.6, 0.6, 0.6, 0.6]           2
#
#   top_10_crew_popularity_mean  \
# 0                    0.676000
# 1                    0.733333
# 2                    0.600000
# 3                    0.784667
# 4                    0.600000
#
#                                                crews  \
# 0  [Germaine Dulac, Serge Sandberg, Paul Parguel,...
# 1  [Gerhard Lamprecht, Willi Herrmann, Lupu Pick,...
# 2                                         [Musidora]
# 3  [Rodrigo Prieto, Hubert Barrero, Eva López Sán...
# 4                  [Arturo Carballo, Ramón de Baños]
#
#              top_10_crew_popularity  tmdb_avgRating tmdb_numVotes  \
# 0        [0.98, 0.6, 0.6, 0.6, 0.6]             6.0             1
# 1    [1.4, 0.6, 0.6, 0.6, 0.6, 0.6]             0.0             0
# 2                             [0.6]             0.0             0
# 3  [1.708, 0.6, 0.6, 0.6, 0.6, 0.6]             8.8             4
# 4                        [0.6, 0.6]             0.0             0
#
#                                             homepage
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  http://www.elccc.com.mx/sitio/index.php/produc...
# 4                                                NaN
#
# [5 rows x 32 columns]

# %%
# get all possible column names
print(function.get_all_columns_name())
# Out:
# ['_id', 'primaryTitle', 'originalTitle', 'isAdult', 'release_year', 'release_date', 'runtimeMinutes', 'genres', 'imdb_avgRating', 'imdb_numVotes', 'Directors', 'casts', 'tmdb_id', 'poster_path', 'original_language', 'popularity', 'budget', 'revenue', 'status', 'tagline', 'overview', 'company_name', 'keywords_name', 'num_of_cast', 'top_10_cast_popularity_mean', 'top_10_cast_popularity', 'num_of_crew', 'top_10_crew_popularity_mean', 'crews', 'top_10_crew_popularity', 'tmdb_avgRating', 'tmdb_numVotes', 'Writers', 'homepage', 'belongs_to_collection']

# %%
# drop selected columns to reduce query size
drop_cols = ['overview', 'tagline', 'originalTitle', 'num_of_cast', 'top_10_cast_popularity_mean'
             , 'top_10_cast_popularity', 'num_of_crew', 'top_10_crew_popularity_mean', 'crews'
             , 'top_10_crew_popularity', 'homepage']
dropped_db = function.get_combined(drop_lst=drop_cols)
dropped_db.head(5)
# Out:
#          _id                    primaryTitle  isAdult  release_year  \
# 0  tt0000574     The Story of the Kelly Gang        0          1906
# 1  tt0000615              Robbery Under Arms        0          1907
# 2  tt0000679  The Fairylogue and Radio-Plays        0          1908
# 3  tt0000846            Un día en Xochimilco        0          1909
# 4  tt0000867                 Fiesta de toros        0          1909
#
#    runtimeMinutes                                             genres  \
# 0            70.0  [Action, Adventure, Biography, History, Drama,...
# 1            60.0                                            [Drama]
# 2           120.0                               [Adventure, Fantasy]
# 3             0.0                                                NaN
# 4             0.0                                                NaN
#
#    imdb_avgRating  imdb_numVotes                     Directors  \
# 0             6.1          622.0                [Charles Tait]
# 1             4.5           14.0            [Charles MacMahon]
# 2             5.2           35.0  [Francis Boggs, Otis Turner]
# 3             NaN            NaN               [Hermanos Alva]
# 4             NaN            NaN               [Hermanos Alva]
#
#                                                casts  ...  popularity budget  \
# 0                        [Elizabeth Tait, John Tait]  ...       2.764      0
# 1  [Jim Gerald, J. Williams, George Merriman, Lan...  ...       0.600      0
# 2  [Frank Burns, L. Frank Baum, George E. Wilson,...  ...       0.600      0
# 3                                                NaN  ...       0.600      0
# 4                                                NaN  ...       0.600      0
#
#   revenue    status                         company_name  \
# 0       0  Released   [Johnson and Gibson, J. & N. Tait]
# 1       0  Released      [MacMahon's Exquisite Pictures]
# 2       0  Released  [The Radio Play Company of America]
# 3       0  Released                                  NaN
# 4       0  Released                                  NaN
#
#                         keywords_name tmdb_avgRating tmdb_numVotes  \
# 0  [silent film, partially lost film]            5.3          21.0
# 1                                 NaN            1.0           1.0
# 2                       [silent film]            1.0           1.0
# 3                                 NaN            5.0           1.0
# 4                                 NaN            5.0           1.0
#
#              Writers  belongs_to_collection
# 0                NaN                    NaN
# 1  [Rolf Boldrewood]                    NaN
# 2    [L. Frank Baum]                    NaN
# 3                NaN                    NaN
# 4                NaN                    NaN
#
# [5 rows x 23 columns]

# %%
function.get_combined(1910, drop_cols, 100)
# Out:
#           _id                      primaryTitle  isAdult  release_year  \
# 0   tt0001112                            Amleto        0          1910
# 1   tt0001141                     The Butterfly        0          1910
# 2   tt0001175                           Camille        0          1912
# 3   tt0001179  Desfile histórico del centenario        0          1910
# 4   tt0001184           Don Juan de Serrallonga        0          1910
# ..        ...                               ...      ...           ...
# 95  tt0003378                A Sister to Carmen        0          1913
# 96  tt0003386                       Sodoms Ende        0          1913
# 97  tt0003419             The Student of Prague        0          1913
# 98  tt0003423                    Die Sumpfblume        0          1913
# 99  tt0003431                  Die Tangokönigin        0          1913
#
#                       genres  imdb_avgRating  imdb_numVotes  \
# 0                    [Drama]             3.7           20.0
# 1                        NaN             NaN            NaN
# 2           [Drama, Romance]             5.8           22.0
# 3                        NaN             NaN            NaN
# 4         [Adventure, Drama]             3.4           11.0
# ..                       ...             ...            ...
# 95                   [Drama]             NaN            NaN
# 96                   [Drama]             7.7            9.0
# 97  [Drama, Fantasy, Horror]             6.5         1850.0
# 98                       NaN             NaN            NaN
# 99                  [Comedy]             5.6            8.0
#
#                                             Directors  \
# 0                                    [Mario Caserini]
# 1                                    [Robert W. Paul]
# 2   [André Calmettes, Louis Mercanton, Henri Pouctal]
# 3                                     [Hermanos Alva]
# 4                   [Ricardo de Baños, Alberto Marro]
# ..                                                ...
# 95                               [Charles L. Gaskill]
# 96                                 [Alexander Moissi]
# 97                        [Stellan Rye, Paul Wegener]
# 98                                       Viggo Larsen
# 99                                         [Max Mack]
#
#                                               Writers  \
# 0                               [William Shakespeare]
# 1                                                 NaN
# 2                              [Alexandre Dumas fils]
# 3                                                 NaN
# 4                                   [Víctor Balaguer]
# ..                                                ...
# 95                                                NaN
# 96                                [Hermann Sudermann]
# 97  [Hanns Heinz Ewers, Alfred de Musset, Klaus Ri...
# 98                                                NaN
# 99                                                NaN
#
#                                                 casts  ...  popularity budget  \
# 0                    [Dante Cappelli, Maria Caserini]  ...       0.600      0
# 1                                                 NaN  ...       0.600      0
# 2   [Lou Tellegen, Paul Capellani, Sarah Bernhardt...  ...       0.600      0
# 3                                                 NaN  ...       0.600      0
# 4      [Cecilio Rodríguez de la Vega, Dolores Puchol]  ...       0.600      0
# ..                                                ...  ...         ...    ...
# 95                                    [Helen Gardner]  ...       0.600      0
# 96  [Alfred Abel, Camilla Eibenschütz, Johanna Ter...  ...       0.600      0
# 97  [Lyda Salmonova, Hanns Heinz Ewers, Lothar Kör...  ...       3.559      0
# 98   [Viggo Larsen, Wanda Treumann, Richard Liebesny]  ...       0.600      0
# 99                          [Olga Engl, Hanni Weisse]  ...       0.600      0
#
#     revenue    status  runtimeMinutes tmdb_avgRating  tmdb_numVotes  \
# 0         0  Released             8.0            1.0              1
# 1         0  Released             2.0            0.0              0
# 2         0  Released            16.0            1.0              1
# 3         0  Released             0.0            5.0              1
# 4         0  Released            58.0            1.0              1
# ..      ...       ...             ...            ...            ...
# 95        0  Released             0.0            0.0              0
# 96        0  Released             0.0            1.0              1
# 97        0  Released            85.0            5.8             38
# 98        0  Released            53.0            0.0              0
# 99        0  Released            60.0            0.0              0
#
#                                           poster_path  \
# 0                                                 NaN
# 1                                                 NaN
# 2   https://www.themoviedb.org/t/p/w600_and_h900_b...
# 3                                                 NaN
# 4   https://www.themoviedb.org/t/p/w600_and_h900_b...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97  https://www.themoviedb.org/t/p/w600_and_h900_b...
# 98                                                NaN
# 99  https://www.themoviedb.org/t/p/w600_and_h900_b...
#
#                              company_name           keywords_name
# 0                                     NaN                     NaN
# 1                                     NaN                     NaN
# 2                         [Le Film d'Art]                     NaN
# 3                                     NaN                     NaN
# 4                         [Hispano Films]                     NaN
# ..                                    ...                     ...
# 95                                    NaN                     NaN
# 96                                    NaN                     NaN
# 97  [Bioskop-Film, Deutsche Bioscop GmbH]  [german expressionism]
# 98                                    NaN   [partially lost film]
# 99                       [Vitascope GmbH]                     NaN
#
# [100 rows x 22 columns]

# %%
movieLens_db = function.get_movieLens()
movieLens_db.head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
movieLens_reviews_db = function.get_movieLens_reviews()
movieLens_reviews_db.head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
