# %%
import scripts.query_database as function
import pandas as pd

# %%
imdb_db = function.get_imdb()

# %%
imdb_db.head(5)
# Out:
#          _id                 primaryTitle                originalTitle  \
# 0  tt0000502                     Bohemios                     Bohemios
# 1  tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2  tt0000615           Robbery Under Arms           Robbery Under Arms
# 3  tt0000630                       Hamlet                       Amleto
# 4  tt0000675                  Don Quijote                  Don Quijote
#
#   isAdult release_year  runtimeMinutes  imdb_avgRating  imdb_numVotes  \
# 0       0         1905           100.0             4.5            8.0
# 1       0         1906            70.0             6.1          622.0
# 2       0         1907             NaN             4.5           14.0
# 3       0         1908             NaN             3.2           11.0
# 4       0         1908             NaN             4.9            9.0
#
#             Directors                                 Writers  \
# 0  [Ricardo de Baños]  [Miguel de Palacios, Guillermo Perrín]
# 1      [Charles Tait]                                     NaN
# 2  [Charles MacMahon]                       [Rolf Boldrewood]
# 3    [Mario Caserini]                   [William Shakespeare]
# 4     [Narciso Cuyàs]        [Miguel de Cervantes y Saavedra]
#
#                                                casts  \
# 0                    [Antonio del Pozo, El Mochuelo]
# 1  [Elizabeth Tait, John Tait, Norman Campbell, B...
# 2  [Jim Gerald, George Merriman, Lance Vane, Will...
# 3                            [Fernanda Negri Pouget]
# 4                                                NaN
#
#                            genres
# 0                             NaN
# 1  [Action, Adventure, Biography]
# 2                         [Drama]
# 3                         [Drama]
# 4                         [Drama]

# %%
tmdb_db = function.get_tmdb()

# %%
tmdb_db.head(5)
# Out:
#          _id  tmdb_id                           genres  \
# 0  tt0000574    20105  [History, Action, Drama, Crime]
# 1  tt0000615   603786                          [Drama]
# 2  tt0000679   470664             [Adventure, Fantasy]
# 3  tt0000846   668839                              NaN
# 4  tt0000867   668836                              NaN
#
#                                          poster_path original_language  \
# 0  https://www.themoviedb.org/t/p/w600_and_h900_b...                en
# 1                                                NaN                en
# 2  https://www.themoviedb.org/t/p/w600_and_h900_b...                en
# 3                                                NaN                en
# 4                                                NaN                en
#
#    popularity  budget  revenue    status  \
# 0       2.764       0        0  Released
# 1       0.600       0        0  Released
# 2       0.600       0        0  Released
# 3       0.600       0        0  Released
# 4       0.600       0        0  Released
#
#                                              tagline  ... num_of_crew  \
# 0  The Most Sensational, The Most Thrilling and I...  ...         5.0
# 1  First filmed version of Rolf Boldrewood's 'Rob...  ...         2.0
# 2                                                NaN  ...         4.0
# 3                                                NaN  ...         NaN
# 4                                                NaN  ...         NaN
#
#   top_10_crew_popularity_mean  \
# 0                     0.60000
# 1                     0.60000
# 2                     0.81625
# 3                         NaN
# 4                         NaN
#
#                                                crews  \
# 0  [Charles Tait, Millard Johnson, Orrie Perry, R...
# 1                [Charles MacMahon, C. Byers Coates]
# 2  [L. Frank Baum, Francis Boggs, Otis Turner, Na...
# 3                                                NaN
# 4                                                NaN
#
#       top_10_crew_popularity         Directors  tmdb_avgRating tmdb_numVotes  \
# 0  [0.6, 0.6, 0.6, 0.6, 0.6]      Charles Tait             5.3            21
# 1                 [0.6, 0.6]  Charles MacMahon             1.0             1
# 2   [1.237, 0.828, 0.6, 0.6]     Francis Boggs             1.0             1
# 3                        NaN               NaN             5.0             1
# 4                        NaN               NaN             5.0             1
#
#            Writers  homepage  belongs_to_collection
# 0              NaN       NaN                    NaN
# 1              NaN       NaN                    NaN
# 2  [L. Frank Baum]       NaN                    NaN
# 3              NaN       NaN                    NaN
# 4              NaN       NaN                    NaN
#
# [5 rows x 32 columns]

# %%
reviews_db = function.get_reviews()

# %%
reviews_db.head(5)
# Out:
#          _id  tmdb_id                                             review
# 0  tt0004972      618  [{'author': 'prabhushakti', 'rating': 10.0, 'u...
# 1  tt0008431   285807  [{'author': 'Le_Schpountz', 'rating': 6.0, 'ur...
# 2  tt0009062    48214  [{'author': 'germish', 'rating': 9.5, 'url': '...
# 3  tt0009143   463115  [{'author': '27B/6', 'rating': None, 'url': 'h...
# 4  tt0010058   352098  [{'author': 'ObscurHollywood', 'rating': None,...

# %%
combined_db = function.get_combined()

# %%
combined_db.head(5)
# Out:
#          _id                    primaryTitle                   originalTitle  \
# 0  tt0000574     The Story of the Kelly Gang     The Story of the Kelly Gang
# 1  tt0000615              Robbery Under Arms              Robbery Under Arms
# 2  tt0000679  The Fairylogue and Radio-Plays  The Fairylogue and Radio-Plays
# 3  tt0000846            Un día en Xochimilco            Un día en Xochimilco
# 4  tt0000867                 Fiesta de toros                 Fiesta de toros
#
#    isAdult  release_year  runtimeMinutes  \
# 0        0          1906            70.0
# 1        0          1907            60.0
# 2        0          1908           120.0
# 3        0          1909             0.0
# 4        0          1909             0.0
#
#                                               genres  imdb_avgRating  \
# 0  [Action, Adventure, Biography, History, Drama,...             6.1
# 1                                            [Drama]             4.5
# 2                               [Adventure, Fantasy]             5.2
# 3                                                NaN             NaN
# 4                                                NaN             NaN
#
#    imdb_numVotes                     Directors  ...  \
# 0          622.0                [Charles Tait]  ...
# 1           14.0            [Charles MacMahon]  ...
# 2           35.0  [Francis Boggs, Otis Turner]  ...
# 3            NaN               [Hermanos Alva]  ...
# 4            NaN               [Hermanos Alva]  ...
#
#                               top_10_cast_popularity  num_of_crew  \
# 0                                         [0.6, 0.6]          5.0
# 1           [0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6]          2.0
# 2  [1.4, 1.237, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6...          4.0
# 3                                                NaN          NaN
# 4                                                NaN          NaN
#
#   top_10_crew_popularity_mean  \
# 0                     0.60000
# 1                     0.60000
# 2                     0.81625
# 3                         NaN
# 4                         NaN
#
#                                                crews  \
# 0  [Charles Tait, Millard Johnson, Orrie Perry, R...
# 1                [Charles MacMahon, C. Byers Coates]
# 2  [L. Frank Baum, Francis Boggs, Otis Turner, Na...
# 3                                                NaN
# 4                                                NaN
#
#       top_10_crew_popularity  tmdb_avgRating  tmdb_numVotes  \
# 0  [0.6, 0.6, 0.6, 0.6, 0.6]             5.3           21.0
# 1                 [0.6, 0.6]             1.0            1.0
# 2   [1.237, 0.828, 0.6, 0.6]             1.0            1.0
# 3                        NaN             5.0            1.0
# 4                        NaN             5.0            1.0
#
#              Writers homepage belongs_to_collection
# 0                NaN      NaN                   NaN
# 1  [Rolf Boldrewood]      NaN                   NaN
# 2    [L. Frank Baum]      NaN                   NaN
# 3                NaN      NaN                   NaN
# 4                NaN      NaN                   NaN
#
# [5 rows x 34 columns]
