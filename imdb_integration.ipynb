# %%
import pandas as pd
import json
import numpy as np
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('127.0.0.1', 27017)
db = client.aoligei
imdb_collection = db.imdb_movies

# %%
movies = pd.read_csv('./Data/raw_data/IMDB/title.basics.tsv', sep='\t')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
movies = movies[movies['titleType']=='movie'].reset_index()

# %%
movies = movies.drop(['index', 'titleType', 'endYear'], axis=1)

# %%
movies = movies.replace('\\N', np.nan)

# %%
movies.head(5)
# Out:
#       tconst                 primaryTitle                originalTitle  \
# 0  tt0000502                     Bohemios                     Bohemios
# 1  tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2  tt0000615           Robbery Under Arms           Robbery Under Arms
# 3  tt0000630                       Hamlet                       Amleto
# 4  tt0000675                  Don Quijote                  Don Quijote
#
#   isAdult startYear runtimeMinutes                      genres
# 0       0      1905            100                         NaN
# 1       0      1906             70  Action,Adventure,Biography
# 2       0      1907            NaN                       Drama
# 3       0      1908            NaN                       Drama
# 4       0      1908            NaN                       Drama

# %%
movies['genres'] = movies.genres.str.split(',')

# %%
ratings = pd.read_csv('./Data/raw_data/IMDB/title.ratings.tsv', sep='\t')

# %%
movies_ratings = movies.merge(ratings, how='left', left_on='tconst', right_on='imdb_id')

# %%
movies_ratings = movies_ratings.set_index('tconst')

# %%
movies_ratings = movies_ratings.drop(['imdb_id'], axis=1)

# %%
principles = pd.read_csv('./Data/raw_data/IMDB/title.principals.tsv', sep='\t', usecols=['tconst','nconst', 'category'])

# %%
principles = principles.replace('\\N', np.nan)

# %%
names = pd.read_csv('./Data/raw_data/IMDB/name.basics.tsv', sep='\t', usecols=['nconst','primaryName'])

# %%
principles_withname = principles.merge(names, on='nconst').drop(['nconst'], axis=1)

# %%
directors = principles_withname[principles_withname['category'] == 'director']

# %%
directors = directors.set_index('tconst')

# %%
helper = movies_ratings.merge(directors, how='left', left_index=True, right_index=True)

# %%
# helper['primaryName'] = helper.primaryName.replace(np.nan, '', regex=True)

# %%
director_list = helper.groupby('tconst').primaryName.apply(list).reset_index()

# %%
director_list = director_list.set_index('tconst')

# %%
movies_dir = movies_ratings.merge(director_list, how='left', left_index=True, right_index=True)

# %%
movies_dir = movies_dir.rename(columns={"primaryName": "Directors"})

# %%
movies_dir.head(5)
# Out:
#                           primaryTitle                originalTitle isAdult  \
# tconst
# tt0000502                     Bohemios                     Bohemios       0
# tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang       0
# tt0000615           Robbery Under Arms           Robbery Under Arms       0
# tt0000630                       Hamlet                       Amleto       0
# tt0000675                  Don Quijote                  Don Quijote       0
#
#           startYear runtimeMinutes                          genres  \
# tconst
# tt0000502      1905            100                             NaN
# tt0000574      1906             70  [Action, Adventure, Biography]
# tt0000615      1907            NaN                         [Drama]
# tt0000630      1908            NaN                         [Drama]
# tt0000675      1908            NaN                         [Drama]
#
#            averageRating  numVotes           Directors
# tconst
# tt0000502            4.5       8.0  [Ricardo de Baños]
# tt0000574            6.1     622.0      [Charles Tait]
# tt0000615            4.5      14.0  [Charles MacMahon]
# tt0000630            3.2      11.0    [Mario Caserini]
# tt0000675            4.9       9.0     [Narciso Cuyàs]

# %%
writers = principles_withname[principles_withname['category'] == 'writer']

# %%
writers = writers.set_index('tconst')

# %%
helper_w = movies_ratings.merge(writers, how='left', left_index=True, right_index=True)

# %%
# helper_w['primaryName'] = helper_w.primaryName.replace(np.nan, '', regex=True)

# %%
writer_list = helper_w.groupby('tconst').primaryName.apply(list).reset_index().set_index('tconst')

# %%
movies_wri = movies_dir.merge(writer_list, how='left', left_index=True, right_index=True).rename(columns={"primaryName": "Writers"})

# %%
movies_wri.head(5)
# Out:
#                           primaryTitle                originalTitle isAdult  \
# tconst
# tt0000502                     Bohemios                     Bohemios       0
# tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang       0
# tt0000615           Robbery Under Arms           Robbery Under Arms       0
# tt0000630                       Hamlet                       Amleto       0
# tt0000675                  Don Quijote                  Don Quijote       0
#
#           startYear runtimeMinutes                          genres  \
# tconst
# tt0000502      1905            100                             NaN
# tt0000574      1906             70  [Action, Adventure, Biography]
# tt0000615      1907            NaN                         [Drama]
# tt0000630      1908            NaN                         [Drama]
# tt0000675      1908            NaN                         [Drama]
#
#            averageRating  numVotes           Directors  \
# tconst
# tt0000502            4.5       8.0  [Ricardo de Baños]
# tt0000574            6.1     622.0      [Charles Tait]
# tt0000615            4.5      14.0  [Charles MacMahon]
# tt0000630            3.2      11.0    [Mario Caserini]
# tt0000675            4.9       9.0     [Narciso Cuyàs]
#
#                                           Writers
# tconst
# tt0000502  [Miguel de Palacios, Guillermo Perrín]
# tt0000574                                   [nan]
# tt0000615                       [Rolf Boldrewood]
# tt0000630                   [William Shakespeare]
# tt0000675        [Miguel de Cervantes y Saavedra]

# %%
cast = principles_withname[(principles_withname['category'] == 'actor') | (principles_withname['category'] == 'actress' )]

# %%
cast = cast.set_index('tconst')

# %%
helper_c = movies_ratings.merge(cast, how='left', left_index=True, right_index=True)

# %%
# helper_c['primaryName'] = helper_c.primaryName.replace(np.nan, '', regex=True)

# %%
cast_list = helper_c.groupby('tconst').primaryName.apply(list).reset_index().set_index('tconst')

# %%
movies_cast = movies_wri.merge(cast_list, how='left', left_index=True, right_index=True).rename(columns={"primaryName": "Casts"})

# %%
movies_cast.head(5)
# Out:
#                           primaryTitle                originalTitle isAdult  \
# tconst
# tt0000502                     Bohemios                     Bohemios       0
# tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang       0
# tt0000615           Robbery Under Arms           Robbery Under Arms       0
# tt0000630                       Hamlet                       Amleto       0
# tt0000675                  Don Quijote                  Don Quijote       0
#
#           startYear runtimeMinutes                          genres  \
# tconst
# tt0000502      1905            100                             NaN
# tt0000574      1906             70  [Action, Adventure, Biography]
# tt0000615      1907            NaN                         [Drama]
# tt0000630      1908            NaN                         [Drama]
# tt0000675      1908            NaN                         [Drama]
#
#            averageRating  numVotes           Directors  \
# tconst
# tt0000502            4.5       8.0  [Ricardo de Baños]
# tt0000574            6.1     622.0      [Charles Tait]
# tt0000615            4.5      14.0  [Charles MacMahon]
# tt0000630            3.2      11.0    [Mario Caserini]
# tt0000675            4.9       9.0     [Narciso Cuyàs]
#
#                                           Writers  \
# tconst
# tt0000502  [Miguel de Palacios, Guillermo Perrín]
# tt0000574                                   [nan]
# tt0000615                       [Rolf Boldrewood]
# tt0000630                   [William Shakespeare]
# tt0000675        [Miguel de Cervantes y Saavedra]
#
#                                                        Casts
# tconst
# tt0000502                    [Antonio del Pozo, El Mochuelo]
# tt0000574  [Elizabeth Tait, John Tait, Norman Campbell, B...
# tt0000615  [Jim Gerald, George Merriman, Lance Vane, Will...
# tt0000630                            [Fernanda Negri Pouget]
# tt0000675                                              [nan]

# %%
movies_cast = movies_cast.reset_index().rename(columns={"tconst": "_id"})

# %%
movies_cast
# Out:
#               _id                                       primaryTitle  \
# 0       tt0000502                                           Bohemios
# 1       tt0000574                        The Story of the Kelly Gang
# 2       tt0000615                                 Robbery Under Arms
# 3       tt0000630                                             Hamlet
# 4       tt0000675                                        Don Quijote
# ...           ...                                                ...
# 571836  tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro
# 571837  tt9916680  De la ilusión al desconcierto: cine colombiano...
# 571838  tt9916706                                    Dankyavar Danka
# 571839  tt9916730                                             6 Gunn
# 571840  tt9916754                     Chico Albuquerque - Revelações
#
#                                             originalTitle isAdult startYear  \
# 0                                                Bohemios       0      1905
# 1                             The Story of the Kelly Gang       0      1906
# 2                                      Robbery Under Arms       0      1907
# 3                                                  Amleto       0      1908
# 4                                             Don Quijote       0      1908
# ...                                                   ...     ...       ...
# 571836        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 571837  De la ilusión al desconcierto: cine colombiano...       0      2007
# 571838                                    Dankyavar Danka       0      2013
# 571839                                             6 Gunn       0      2017
# 571840                     Chico Albuquerque - Revelações       0      2013
#
#        runtimeMinutes                          genres  averageRating  \
# 0                 100                             NaN            4.5
# 1                  70  [Action, Adventure, Biography]            6.1
# 2                 NaN                         [Drama]            4.5
# 3                 NaN                         [Drama]            3.2
# 4                 NaN                         [Drama]            4.9
# ...               ...                             ...            ...
# 571836             57                   [Documentary]            NaN
# 571837            100                   [Documentary]            NaN
# 571838            NaN                        [Comedy]            NaN
# 571839            116                             NaN            NaN
# 571840             49                   [Documentary]            NaN
#
#         numVotes                                Directors  \
# 0            8.0                       [Ricardo de Baños]
# 1          622.0                           [Charles Tait]
# 2           14.0                       [Charles MacMahon]
# 3           11.0                         [Mario Caserini]
# 4            9.0                          [Narciso Cuyàs]
# ...          ...                                      ...
# 571836       NaN   [Angela Gurgel, Ana Célia de Oliveira]
# 571837       NaN                            [Luis Ospina]
# 571838       NaN                          [Kanchan Nayak]
# 571839       NaN                           [Kiran Gawade]
# 571840       NaN  [Angela Gurgel, Vinicius Augusto Bozzo]
#
#                                        Writers  \
# 0       [Miguel de Palacios, Guillermo Perrín]
# 1                                        [nan]
# 2                            [Rolf Boldrewood]
# 3                        [William Shakespeare]
# 4             [Miguel de Cervantes y Saavedra]
# ...                                        ...
# 571836                                   [nan]
# 571837                           [Diego Rojas]
# 571838                          [Sudhir Nikam]
# 571839                                   [nan]
# 571840                                   [nan]
#
#                                                     Casts
# 0                         [Antonio del Pozo, El Mochuelo]
# 1       [Elizabeth Tait, John Tait, Norman Campbell, B...
# 2       [Jim Gerald, George Merriman, Lance Vane, Will...
# 3                                 [Fernanda Negri Pouget]
# 4                                                   [nan]
# ...                                                   ...
# 571836                              [Oldair Soares Ammom]
# 571837                                              [nan]
# 571838  [Makarand Anaspure, Anvay Bendre, Suvarna Kale...
# 571839  [Sunil Barve, Bhushan Pradhan, Pranav Raorane,...
# 571840                                              [nan]
#
# [571841 rows x 12 columns]

# %%
movies_tojson = movies_cast.to_json(orient="records")
result = json.loads(movies_tojson)

# %%
imdb_collection.insert_many(result)
